# %% [markdown]
# # YouTube Downloader

# %%
import yt_dlp
import os

url = 'https://www.youtube.com/watch?v=alDhOLhbkbY'
video_id = 'alDhOLhbkbY'
print(f"Downloading video {video_id}...")
video_dir = os.path.join('../../data/video', 'meo')
os.makedirs(video_dir, exist_ok=True)
video_path = os.path.join(video_dir, f"{video_id}.mp4")

if os.path.isfile(video_path):
    print(f"Video already downloaded: {video_path}")
else:
    ydl_opts = {
        'format': 'best',
        'outtmpl': str(video_path),
        'quiet': False,
        'cookiefile': '../../data/cookie/cookie.txt'
    }
    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        ydl.download([url])
# Out:
# Downloading video alDhOLhbkbY...
# [youtube] Extracting URL: https://www.youtube.com/watch?v=alDhOLhbkbY
# [youtube] alDhOLhbkbY: Downloading webpage
# WARNING: [youtube] The provided YouTube account cookies are no longer valid. They have likely been rotated in the browser as a security measure. For tips on how to effectively export YouTube cookies, refer to  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies .
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] alDhOLhbkbY: Downloading android vr player API JSON
# WARNING: [youtube] The provided YouTube account cookies are no longer valid. They have likely been rotated in the browser as a security measure. For tips on how to effectively export YouTube cookies, refer to  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies .
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] alDhOLhbkbY: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# ---------------------------------------------------------------------------
# ExtractorError                            Traceback (most recent call last)
# File ~/FPT/video_rag_chatbot/.venv/lib/python3.11/site-packages/yt_dlp/YoutubeDL.py:1698, in YoutubeDL._handle_extraction_exceptions.<locals>.wrapper(self, *args, **kwargs)
#    1697 try:
# -> 1698     return func(self, *args, **kwargs)
#    1699 except (CookieLoadError, DownloadCancelled, LazyList.IndexError, PagedList.IndexError):
#
# File ~/FPT/video_rag_chatbot/.venv/lib/python3.11/site-packages/yt_dlp/YoutubeDL.py:1833, in YoutubeDL.__extract_info(self, url, ie, download, extra_info, process)
#    1832 try:
# -> 1833     ie_result = ie.extract(url)
#    1834 except UserNotLive as e:
#
# File ~/FPT/video_rag_chatbot/.venv/lib/python3.11/site-packages/yt_dlp/extractor/common.py:765, in InfoExtractor.extract(self, url)
#     763 self.to_screen('Extracting URL: %s' % (
#     764     url if self.get_param('verbose') else truncate_string(url, 100, 20)))
# --> 765 ie_result = self._real_extract(url)
#     766 if ie_result is None:
#
# File ~/FPT/video_rag_chatbot/.venv/lib/python3.11/site-packages/yt_dlp/extractor/youtube/_video.py:4061, in YoutubeIE._real_extract(self, url)
#    4055             reason = (
#    4056                 f'{remove_end(reason.strip(), ".")}. {"Your account" if self.is_authenticated else "The current session"} '
#    4057                 f'has been rate-limited by YouTube for up to an hour. It is recommended to use `-t sleep` to add a delay '
#    4058                 f'between video requests to avoid exceeding the rate limit. For more information, refer to  '
#    4059                 f'https://github.com/yt-dlp/yt-dlp/wiki/Extractors#this-content-isnt-available-try-again-later'
#    4060             )
# -> 4061         self.raise_no_formats(reason, expected=True)
#    4063 keywords = get_first(video_details, 'keywords', expected_type=list) or []
#
# File ~/FPT/video_rag_chatbot/.venv/lib/python3.11/site-packages/yt_dlp/extractor/common.py:1277, in InfoExtractor.raise_no_formats(self, msg, expected, video_id)
#    1276 else:
# -> 1277     raise ExtractorError(msg, expected=expected, video_id=video_id)
#
# ExtractorError: [youtube] alDhOLhbkbY: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
#
# During handling of the above exception, another exception occurred:
#
# DownloadError                             Traceback (most recent call last)
# Cell In[9], line 21
#      14 ydl_opts = {
#      15     'format': 'best',
#      16     'outtmpl': str(video_path),
#      17     'quiet': False,
#      18     'cookiefile': '../../data/cookie/cookie.txt'
#      19 }
#      20 with yt_dlp.YoutubeDL(ydl_opts) as ydl:
# ---> 21     ydl.download([url])
#
# File ~/FPT/video_rag_chatbot/.venv/lib/python3.11/site-packages/yt_dlp/YoutubeDL.py:3670, in YoutubeDL.download(self, url_list)
#    3667     raise SameFileError(outtmpl)
#    3669 for url in url_list:
# -> 3670     self.__download_wrapper(self.extract_info)(
#    3671         url, force_generic_extractor=self.params.get('force_generic_extractor', False))
#    3673 return self._download_retcode
#
# File ~/FPT/video_rag_chatbot/.venv/lib/python3.11/site-packages/yt_dlp/YoutubeDL.py:3643, in YoutubeDL.__download_wrapper.<locals>.wrapper(*args, **kwargs)
#    3640 @functools.wraps(func)
#    3641 def wrapper(*args, **kwargs):
#    3642     try:
# -> 3643         res = func(*args, **kwargs)
#    3644     except CookieLoadError:
#    3645         raise
#
# File ~/FPT/video_rag_chatbot/.venv/lib/python3.11/site-packages/yt_dlp/YoutubeDL.py:1687, in YoutubeDL.extract_info(self, url, download, ie_key, extra_info, process, force_generic_extractor)
#    1685             raise ExistingVideoReached
#    1686         break
# -> 1687     return self.__extract_info(url, self.get_info_extractor(key), download, extra_info, process)
#    1688 else:
#    1689     extractors_restricted = self.params.get('allowed_extractors') not in (None, ['default'])
#
# File ~/FPT/video_rag_chatbot/.venv/lib/python3.11/site-packages/yt_dlp/YoutubeDL.py:1716, in YoutubeDL._handle_extraction_exceptions.<locals>.wrapper(self, *args, **kwargs)
#    1714     self.report_error(msg)
#    1715 except ExtractorError as e:  # An error we somewhat expected
# -> 1716     self.report_error(str(e), e.format_traceback())
#    1717 except Exception as e:
#    1718     if self.params.get('ignoreerrors'):
#
# File ~/FPT/video_rag_chatbot/.venv/lib/python3.11/site-packages/yt_dlp/YoutubeDL.py:1154, in YoutubeDL.report_error(self, message, *args, **kwargs)
#    1149 def report_error(self, message, *args, **kwargs):
#    1150     """
#    1151     Do the same as trouble, but prefixes the message with 'ERROR:', colored
#    1152     in red if stderr is a tty file.
#    1153     """
# -> 1154     self.trouble(f'{self._format_err("ERROR:", self.Styles.ERROR)} {message}', *args, **kwargs)
#
# File ~/FPT/video_rag_chatbot/.venv/lib/python3.11/site-packages/yt_dlp/YoutubeDL.py:1093, in YoutubeDL.trouble(self, message, tb, is_error)
#    1091     else:
#    1092         exc_info = sys.exc_info()
# -> 1093     raise DownloadError(message, exc_info)
#    1094 self._download_retcode = 1
#
# DownloadError: ERROR: [youtube] alDhOLhbkbY: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 yt_dlp.__version__
#
# AttributeError: module 'yt_dlp' has no attribute '__version__'
