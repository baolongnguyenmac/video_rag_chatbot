# %% [markdown]
# # Vector DB

# %%
import os

os.getenv("GOOGLE_API_KEY")
# Out:
# 'AIzaSyBNNid8RGW3GpKfqES83uPxRbabnKnARcA'

# %%
# !uv pip install google-genai
# Out:
# Using Python 3.11.2 environment at: /home/nblong/Dropbox/Project/ops/video_rag_chatbot/.venv
# Resolved 25 packages in 1.04s
# ⠙ Preparing packages... (0/5)
# ⠙ Preparing packages... (0/5)-------------------     0 B/47.04 KiB
# ⠙ Preparing packages... (0/5)------------------- 14.88 KiB/47.04 KiB
# ⠙ Preparing packages... (0/5)------------------- 14.88 KiB/47.04 KiB
# pycparser            ------------------------------ 14.88 KiB/47.04 KiB
# ⠙ Preparing packages... (0/5)-------------------     0 B/742.76 KiB
# pycparser            ------------------------------ 30.88 KiB/47.04 KiB
# ⠙ Preparing packages... (0/5)-------------------     0 B/742.76 KiB
# pycparser            ------------------------------ 30.88 KiB/47.04 KiB
# ⠙ Preparing packages... (0/5)-------------------     0 B/742.76 KiB
# pycparser            ------------------------------ 30.88 KiB/47.04 KiB
# ⠙ Preparing packages... (0/5)-------------------     0 B/742.76 KiB
# pycparser            ------------------------------ 30.88 KiB/47.04 KiB
# cffi                 ------------------------------     0 B/210.52 KiB
# ⠙ Preparing packages... (0/5)-------------------     0 B/742.76 KiB
# pycparser            ------------------------------ 30.88 KiB/47.04 KiB
# cffi                 ------------------------------     0 B/210.52 KiB
# ⠙ Preparing packages... (0/5)-------------------     0 B/742.76 KiB
# pycparser            ------------------------------ 30.88 KiB/47.04 KiB
# cffi                 ------------------------------     0 B/210.52 KiB
# ⠙ Preparing packages... (0/5)-------------------     0 B/742.76 KiB
# pycparser            ------------------------------ 30.88 KiB/47.04 KiB
# cffi                 ------------------------------     0 B/210.52 KiB
# ⠙ Preparing packages... (0/5)-------------------     0 B/742.76 KiB
# pycparser            ------------------------------ 30.88 KiB/47.04 KiB
# cffi                 ------------------------------     0 B/210.52 KiB
# google-auth          ------------------------------     0 B/235.09 KiB
# ⠙ Preparing packages... (0/5)-------------------     0 B/742.76 KiB
# pycparser            ------------------------------ 46.88 KiB/47.04 KiB
# cffi                 ------------------------------     0 B/210.52 KiB
# google-auth          ------------------------------     0 B/235.09 KiB
# ⠙ Preparing packages... (0/5)-------------------     0 B/742.76 KiB
# pycparser            ------------------------------ 47.04 KiB/47.04 KiB
# cffi                 ------------------------------     0 B/210.52 KiB
# google-auth          ------------------------------     0 B/235.09 KiB
# ⠙ Preparing packages... (0/5)-------------------     0 B/742.76 KiB
# pycparser            ------------------------------ 47.04 KiB/47.04 KiB
# cffi                 ------------------------------     0 B/210.52 KiB
# google-auth          ------------------------------     0 B/235.09 KiB
# ⠙ Preparing packages... (0/5)-------------------     0 B/742.76 KiB
# cffi                 ------------------------------     0 B/210.52 KiB
# google-auth          ------------------------------     0 B/235.09 KiB
# ⠙ Preparing packages... (0/5)-------------------     0 B/742.76 KiB
# cffi                 ------------------------------     0 B/210.52 KiB
# google-auth          ------------------------------ 16.00 KiB/235.09 KiB
# ⠙ Preparing packages... (0/5)-------------------     0 B/742.76 KiB
# cffi                 ------------------------------     0 B/210.52 KiB
# google-auth          ------------------------------ 32.00 KiB/235.09 KiB
# ⠙ Preparing packages... (0/5)-------------------     0 B/742.76 KiB
# cffi                 ------------------------------     0 B/210.52 KiB
# google-auth          ------------------------------ 48.00 KiB/235.09 KiB
# ⠙ Preparing packages... (0/5)-------------------     0 B/742.76 KiB
# cffi                 ------------------------------     0 B/210.52 KiB
# google-auth          ------------------------------ 60.78 KiB/235.09 KiB
# ⠙ Preparing packages... (0/5)-------------------     0 B/742.76 KiB
# cffi                 ------------------------------ 16.00 KiB/210.52 KiB
# google-auth          ------------------------------ 76.78 KiB/235.09 KiB
# google-genai         ------------------------------ 32.00 KiB/742.76 KiB
# ⠹ Preparing packages... (1/5)-------------------     0 B/4.25 MiB
# cffi                 ------------------------------ 47.50 KiB/210.52 KiB
# google-auth          ------------------------------ 108.78 KiB/235.09 KiB
# google-genai         ------------------------------ 48.00 KiB/742.76 KiB
# ⠹ Preparing packages... (1/5)-------------------     0 B/4.25 MiB
# cffi                 ------------------------------ 61.13 KiB/210.52 KiB
# google-auth          ------------------------------ 124.78 KiB/235.09 KiB
# google-genai         ------------------------------ 79.03 KiB/742.76 KiB
# ⠹ Preparing packages... (1/5)------------------- 60.25 KiB/4.25 MiB
# cffi                 ------------------------------ 77.13 KiB/210.52 KiB
# google-auth          ------------------------------ 140.78 KiB/235.09 KiB
# google-genai         ------------------------------ 95.03 KiB/742.76 KiB
# ⠹ Preparing packages... (1/5)------------------- 76.25 KiB/4.25 MiB
# cffi                 ------------------------------ 109.13 KiB/210.52 KiB
# google-auth          ------------------------------ 172.78 KiB/235.09 KiB
# google-genai         ------------------------------ 111.03 KiB/742.76 KiB
# ⠸ Preparing packages... (1/5)------------------- 92.14 KiB/4.25 MiB
# cffi                 ------------------------------ 125.13 KiB/210.52 KiB
# google-auth          ------------------------------ 188.78 KiB/235.09 KiB
# google-genai         ------------------------------ 127.03 KiB/742.76 KiB
# ⠸ Preparing packages... (1/5)------------------- 124.25 KiB/4.25 MiB
# cffi                 ------------------------------ 157.13 KiB/210.52 KiB
# google-auth          ------------------------------ 220.78 KiB/235.09 KiB
# google-genai         ------------------------------ 159.03 KiB/742.76 KiB
# ⠸ Preparing packages... (1/5)------------------- 124.25 KiB/4.25 MiB
# cffi                 ------------------------------ 172.81 KiB/210.52 KiB
# google-genai         ------------------------------ 175.03 KiB/742.76 KiB
# ⠸ Preparing packages... (1/5)------------------- 124.25 KiB/4.25 MiB
# cffi                 ------------------------------ 189.13 KiB/210.52 KiB
# google-genai         ------------------------------ 191.03 KiB/742.76 KiB
# ⠸ Preparing packages... (1/5)------------------- 156.25 KiB/4.25 MiB
# cffi                 ------------------------------ 205.13 KiB/210.52 KiB
# google-genai         ------------------------------ 207.03 KiB/742.76 KiB
# ⠸ Preparing packages... (1/5)------------------- 204.25 KiB/4.25 MiB
# google-genai         ------------------------------ 223.03 KiB/742.76 KiB
# ⠼ Preparing packages... (3/5)------------------- 204.25 KiB/4.25 MiB
# google-genai         ------------------------------ 239.03 KiB/742.76 KiB
# ⠼ Preparing packages... (3/5)------------------- 246.75 KiB/4.25 MiB
# google-genai         ------------------------------ 287.03 KiB/742.76 KiB
# ⠼ Preparing packages... (3/5)------------------- 284.25 KiB/4.25 MiB
# google-genai         ------------------------------ 351.03 KiB/742.76 KiB
# ⠼ Preparing packages... (3/5)------------------- 316.25 KiB/4.25 MiB
# google-genai         ------------------------------ 399.03 KiB/742.76 KiB
# ⠴ Preparing packages... (3/5)------------------- 348.25 KiB/4.25 MiB
# google-genai         ------------------------------ 447.03 KiB/742.76 KiB
# ⠴ Preparing packages... (3/5)------------------- 380.25 KiB/4.25 MiB
# google-genai         ------------------------------ 463.03 KiB/742.76 KiB
# ⠴ Preparing packages... (3/5)------------------- 476.25 KiB/4.25 MiB
# google-genai         ------------------------------ 511.03 KiB/742.76 KiB
# ⠴ Preparing packages... (3/5)------------------- 508.25 KiB/4.25 MiB
# google-genai         ------------------------------ 527.03 KiB/742.76 KiB
# ⠦ Preparing packages... (3/5)------------------- 588.25 KiB/4.25 MiB
# google-genai         ------------------------------ 575.03 KiB/742.76 KiB
# ⠦ Preparing packages... (3/5)------------------- 636.14 KiB/4.25 MiB
# google-genai         ------------------------------ 639.03 KiB/742.76 KiB
# ⠦ Preparing packages... (3/5)------------------- 652.25 KiB/4.25 MiB
# google-genai         ------------------------------ 687.03 KiB/742.76 KiB
# ⠦ Preparing packages... (3/5)------------------- 700.25 KiB/4.25 MiB
# google-genai         ------------------------------ 719.03 KiB/742.76 KiB
# ⠦ Preparing packages... (3/5)------------------- 764.25 KiB/4.25 MiB
# ⠧ Preparing packages... (4/5)------------------- 812.25 KiB/4.25 MiB
# ⠧ Preparing packages... (4/5)------------------- 812.25 KiB/4.25 MiB
# ⠧ Preparing packages... (4/5)------------------- 908.25 KiB/4.25 MiB
# ⠧ Preparing packages... (4/5)------------------- 988.25 KiB/4.25 MiB
# ⠇ Preparing packages... (4/5)------------------- 1.07 MiB/4.25 MiB
# ⠇ Preparing packages... (4/5)------------------- 1.13 MiB/4.25 MiB
# ⠇ Preparing packages... (4/5)------------------- 1.23 MiB/4.25 MiB
# ⠇ Preparing packages... (4/5)------------------- 1.32 MiB/4.25 MiB
# ⠋ Preparing packages... (4/5)------------------- 1.40 MiB/4.25 MiB
# ⠋ Preparing packages... (4/5)------------------- 1.50 MiB/4.25 MiB
# ⠋ Preparing packages... (4/5)------------------- 1.59 MiB/4.25 MiB
# ⠋ Preparing packages... (4/5)------------------- 1.67 MiB/4.25 MiB
# ⠙ Preparing packages... (4/5)m------------------ 1.76 MiB/4.25 MiB
# ⠙ Preparing packages... (4/5)m------------------ 1.82 MiB/4.25 MiB
# ⠙ Preparing packages... (4/5)2m----------------- 1.95 MiB/4.25 MiB
# ⠙ Preparing packages... (4/5)---------------- 2.01 MiB/4.25 MiB
# ⠹ Preparing packages... (4/5)---------------- 2.10 MiB/4.25 MiB
# ⠹ Preparing packages... (4/5)--------------- 2.18 MiB/4.25 MiB
# ⠹ Preparing packages... (4/5)m-------------- 2.28 MiB/4.25 MiB
# ⠹ Preparing packages... (4/5)m-------------- 2.39 MiB/4.25 MiB
# ⠸ Preparing packages... (4/5)0m------------- 2.45 MiB/4.25 MiB
# ⠸ Preparing packages... (4/5)0m------------- 2.53 MiB/4.25 MiB
# ⠸ Preparing packages... (4/5)30m------------ 2.64 MiB/4.25 MiB
# ⠸ Preparing packages... (4/5)----------- 2.72 MiB/4.25 MiB
# ⠼ Preparing packages... (4/5)----------- 2.83 MiB/4.25 MiB
# ⠼ Preparing packages... (4/5)---------- 2.87 MiB/4.25 MiB
# ⠼ Preparing packages... (4/5)---------- 2.98 MiB/4.25 MiB
# ⠼ Preparing packages... (4/5)---------- 3.07 MiB/4.25 MiB
# ⠴ Preparing packages... (4/5)---------- 3.15 MiB/4.25 MiB
# ⠴ Preparing packages... (4/5)---------- 3.25 MiB/4.25 MiB
# ⠴ Preparing packages... (4/5)---------- 3.33 MiB/4.25 MiB
# ⠴ Preparing packages... (4/5)---------- 3.42 MiB/4.25 MiB
# ⠦ Preparing packages... (4/5)---------- 3.51 MiB/4.25 MiB
# ⠦ Preparing packages... (4/5)---------- 3.58 MiB/4.25 MiB
# ⠦ Preparing packages... (4/5)---------- 3.67 MiB/4.25 MiB
# ⠦ Preparing packages... (4/5)---------- 3.76 MiB/4.25 MiB
# ⠧ Preparing packages... (4/5)---------- 3.86 MiB/4.25 MiB
# ⠧ Preparing packages... (4/5)---------- 3.94 MiB/4.25 MiB
# ⠧ Preparing packages... (4/5)---------- 4.03 MiB/4.25 MiB
# ⠧ Preparing packages... (4/5)---------- 4.14 MiB/4.25 MiB
# Prepared 5 packages in 3.17s
# Uninstalled 1 package in 15ms
# Installed 5 packages in 23ms
#  + cffi==2.0.0
#  + cryptography==46.0.6
#  - google-auth==2.40.3
#  + google-auth==2.49.1
#  + google-genai==1.70.0
#  + pycparser==3.0

# %%
from google import genai

client = genai.Client()

result = client.models.embed_content(
    model="gemini-embedding-001",
    contents="What is the meaning of life?"
)

print(result.embeddings)
# Out:
# [ContentEmbedding(
#   values=[
#     -0.022374554,
#     -0.004560777,
#     0.013309286,
#     -0.0545072,
#     -0.02090443,
#     <... 3067 more items ...>,
#   ]
# )]

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings

embeddings = GoogleGenerativeAIEmbeddings(model="gemini-embedding-2-preview")
vector = embeddings.embed_query("hello, world!")
vector[:5]
# Out:
# ---------------------------------------------------------------------------
# _InactiveRpcError                         Traceback (most recent call last)
# File ~/Dropbox/Project/ops/video_rag_chatbot/.venv/lib/python3.11/site-packages/google/api_core/grpc_helpers.py:65, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      64 try:
# ---> 65     return callable_(*args, **kwargs)
#      66 except grpc.RpcError as exc:
#
# File ~/Dropbox/Project/ops/video_rag_chatbot/.venv/lib/python3.11/site-packages/grpc/_interceptor.py:277, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     268 def __call__(
#     269     self,
#     270     request: Any,
#    (...)    275     compression: Optional[grpc.Compression] = None,
#     276 ) -> Any:
# --> 277     response, ignored_call = self._with_call(
#     278         request,
#     279         timeout=timeout,
#     280         metadata=metadata,
#     281         credentials=credentials,
#     282         wait_for_ready=wait_for_ready,
#     283         compression=compression,
#     284     )
#     285     return response
#
# File ~/Dropbox/Project/ops/video_rag_chatbot/.venv/lib/python3.11/site-packages/grpc/_interceptor.py:332, in _UnaryUnaryMultiCallable._with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     329 call = self._interceptor.intercept_unary_unary(
#     330     continuation, client_call_details, request
#     331 )
# --> 332 return call.result(), call
#
# File ~/Dropbox/Project/ops/video_rag_chatbot/.venv/lib/python3.11/site-packages/grpc/_channel.py:440, in _InactiveRpcError.result(self, timeout)
#     439 """See grpc.Future.result."""
# --> 440 raise self
#
# File ~/Dropbox/Project/ops/video_rag_chatbot/.venv/lib/python3.11/site-packages/grpc/_interceptor.py:315, in _UnaryUnaryMultiCallable._with_call.<locals>.continuation(new_details, request)
#     314 try:
# --> 315     response, call = self._thunk(new_method).with_call(
#     316         request,
#     317         timeout=new_timeout,
#     318         metadata=new_metadata,
#     319         credentials=new_credentials,
#     320         wait_for_ready=new_wait_for_ready,
#     321         compression=new_compression,
#     322     )
#     323     return _UnaryOutcome(response, call)
#
# File ~/Dropbox/Project/ops/video_rag_chatbot/.venv/lib/python3.11/site-packages/grpc/_channel.py:1198, in _UnaryUnaryMultiCallable.with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1192 (
#    1193     state,
#    1194     call,
#    1195 ) = self._blocking(
#    1196     request, timeout, metadata, credentials, wait_for_ready, compression
#    1197 )
# -> 1198 return _end_unary_response_blocking(state, call, True, None)
#
# File ~/Dropbox/Project/ops/video_rag_chatbot/.venv/lib/python3.11/site-packages/grpc/_channel.py:1006, in _end_unary_response_blocking(state, call, with_call, deadline)
#    1005 else:
# -> 1006     raise _InactiveRpcError(state)
#
# _InactiveRpcError: <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.INVALID_ARGUMENT
# 	details = "* EmbedContentRequest.model: unexpected model name format
# "
# 	debug_error_string = "UNKNOWN:Error received from peer ipv4:172.253.118.95:443 {grpc_message:"* EmbedContentRequest.model: unexpected model name format\n", grpc_status:3}"
# >
#
# The above exception was the direct cause of the following exception:
#
# InvalidArgument                           Traceback (most recent call last)
# File ~/Dropbox/Project/ops/video_rag_chatbot/.venv/lib/python3.11/site-packages/langchain_google_genai/embeddings.py:264, in GoogleGenerativeAIEmbeddings.embed_query(self, text, task_type, title, output_dimensionality)
#     258     request: EmbedContentRequest = self._prepare_request(
#     259         text=text,
#     260         task_type=task_type,
#     261         title=title,
#     262         output_dimensionality=output_dimensionality,
#     263     )
# --> 264     result: EmbedContentResponse = self.client.embed_content(request)
#     265 except Exception as e:
#
# File ~/Dropbox/Project/ops/video_rag_chatbot/.venv/lib/python3.11/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py:1305, in GenerativeServiceClient.embed_content(self, request, model, content, retry, timeout, metadata)
#    1304 # Send the request.
# -> 1305 response = rpc(
#    1306     request,
#    1307     retry=retry,
#    1308     timeout=timeout,
#    1309     metadata=metadata,
#    1310 )
#    1312 # Done; return the response.
#
# File ~/Dropbox/Project/ops/video_rag_chatbot/.venv/lib/python3.11/site-packages/google/api_core/gapic_v1/method.py:113, in _GapicCallable.__call__(self, timeout, retry, *args, **kwargs)
#     111     kwargs["metadata"] = metadata
# --> 113 return wrapped_func(*args, **kwargs)
#
# File ~/Dropbox/Project/ops/video_rag_chatbot/.venv/lib/python3.11/site-packages/google/api_core/retry.py:349, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     346 sleep_generator = exponential_sleep_generator(
#     347     self._initial, self._maximum, multiplier=self._multiplier
#     348 )
# --> 349 return retry_target(
#     350     target,
#     351     self._predicate,
#     352     sleep_generator,
#     353     self._timeout,
#     354     on_error=on_error,
#     355 )
#
# File ~/Dropbox/Project/ops/video_rag_chatbot/.venv/lib/python3.11/site-packages/google/api_core/retry.py:191, in retry_target(target, predicate, sleep_generator, timeout, on_error, **kwargs)
#     190 try:
# --> 191     return target()
#     193 # pylint: disable=broad-except
#     194 # This function explicitly must deal with broad exceptions.
#
# File ~/Dropbox/Project/ops/video_rag_chatbot/.venv/lib/python3.11/site-packages/google/api_core/timeout.py:120, in TimeToDeadlineTimeout.__call__.<locals>.func_with_timeout(*args, **kwargs)
#     118     kwargs["timeout"] = max(0, self._timeout - time_since_first_attempt)
# --> 120 return func(*args, **kwargs)
#
# File ~/Dropbox/Project/ops/video_rag_chatbot/.venv/lib/python3.11/site-packages/google/api_core/grpc_helpers.py:67, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      66 except grpc.RpcError as exc:
# ---> 67     raise exceptions.from_grpc_error(exc) from exc
#
# InvalidArgument: 400 * EmbedContentRequest.model: unexpected model name format
#
#
# The above exception was the direct cause of the following exception:
#
# GoogleGenerativeAIError                   Traceback (most recent call last)
# Cell In[2], line 4
#       1 from langchain_google_genai import GoogleGenerativeAIEmbeddings
#       3 embeddings = GoogleGenerativeAIEmbeddings(model="gemini-embedding-2-preview")
# ----> 4 vector = embeddings.embed_query("hello, world!")
#       5 vector[:5]
#
# File ~/Dropbox/Project/ops/video_rag_chatbot/.venv/lib/python3.11/site-packages/langchain_google_genai/embeddings.py:266, in GoogleGenerativeAIEmbeddings.embed_query(self, text, task_type, title, output_dimensionality)
#     264     result: EmbedContentResponse = self.client.embed_content(request)
#     265 except Exception as e:
# --> 266     raise GoogleGenerativeAIError(f"Error embedding content: {e}") from e
#     267 return list(result.embedding.values)
#
# GoogleGenerativeAIError: Error embedding content: 400 * EmbedContentRequest.model: unexpected model name format

# %%
from langchain_chroma.vectorstores import Chroma

vector_store:Chroma = Chroma(
    collection_name='test',
    embedding_function=,
    persist_directory=persist_directory
)
